# %% [markdown]
# ### Задание 1
# Скачайте с сайта grouplens.org...movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
import pandas as pd

# %%
data = pd.read_csv('movies.csv')
data.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
rating = pd.read_csv('ratings.csv')
rating.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %% [markdown]
# ### Объединим рейтинги с названиями фильмов

# %%
joined = rating.merge(data, on ='movieId', how ='left')
joined.head()
# Out:
#    userId  movieId  rating  timestamp                        title  \
# 0       1        1     4.0  964982703             Toy Story (1995)
# 1       1        3     4.0  964981247      Grumpier Old Men (1995)
# 2       1        6     4.0  964982224                  Heat (1995)
# 3       1       47     5.0  964983815  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0  964982931   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %% [markdown]
# ### Посчитаем, какой фильм получил больше всего оценок 5

# %%
best_movies = joined[joined['rating'] == 5]
best_movies['title'].value_counts()
# Out:
# Shawshank Redemption, The (1994)             153
# Pulp Fiction (1994)                          123
# Forrest Gump (1994)                          116
# Matrix, The (1999)                           109
# Star Wars: Episode IV - A New Hope (1977)    104
#                                             ...
# Buena Vista Social Club (1999)                 1
# Exorcist III, The (1990)                       1
# Front of the Class (2008)                      1
# Spy Who Loved Me, The (1977)                   1
# Benji the Hunted (1987)                        1
# Name: title, Length: 2954, dtype: int64

# %% [markdown]
# ### Задание 2
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
data = pd.read_csv('power.csv')
data['country'].head()
# Out:
# 0    Austria
# 1    Austria
# 2    Belgium
# 3    Belgium
# 4    Belgium
# Name: country, dtype: object

# %%
summ = 0
e_use = pd.read_csv('power.csv', 'r', delimiter=',')
e_use2 = e_use[(e_use['year']>=2005)&(e_use['year']<=2010)&(e_use['quantity']>0)]
e_use3 = e_use2[e_use2.category.isin([4,12,21])]
summ = e_use3[e_use3.country.str.contains('|'.join(['Lat','Lit','Est']))]['quantity'].sum()
print('суммарное потребление: {}'.format(summ))
# Out:
# суммарное потребление: 240580.0

# %% [markdown]
# ### Задание 3
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.

# %%
import pymysql

# %%
page_url = 'https://www.finam.ru/quotes/indices/'
df = pd.read_html(page_url)
df[0]
# Out:
#     Unnamed: 0                    Инструмент Посл. сделка % Изм. цены  \
# 0          NaN                    Индекс РТС     1603.1 ₽      -0.56%
# 1          NaN            Индекс МосБиржи 10    5732.47 ₽      -0.89%
# 2          NaN               Индекс МосБиржи    3770.15 ₽      -0.78%
# 3          NaN                CSI300 (Китай)     5094.773       -1.1%
# 4          NaN           ASX200 (Австралия)*       7348.1       0.17%
# 5          NaN            Bovespa (Бразилия)    125960.26      -1.18%
# 6          NaN            BSE Sensex (Индия)     53140.06      -0.04%
# 7          NaN                CSI200 (Китай)     5603.228          0%
# 8          NaN           Hang Seng (Гонконг)     28004.68       0.03%
# 9          NaN                 KOSPI (Корея)      3276.91      -0.28%
# 10         NaN            Merval (Аргентина)      63090.8      -0.62%
# 11         NaN            MOEXREPO акц 12:30       5.76 ₽       0.35%
# ...
